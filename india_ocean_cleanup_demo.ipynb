# %% [markdown]
# # Adding India Locations to Ocean Cleanup Data
#
# This notebook demonstrates how to add India locations to your existing USA-based ocean cleanup data visualization.
#
# ## Overview
# 1. Load existing USA data
# 2. Load sample India data
# 3. Create combined global map
# 4. Create India-focused map
